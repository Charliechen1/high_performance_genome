# %% [markdown]
# ### 1. Preprocess Data

# %%
import numpy as np
import torch
import scipy.sparse
import os
import pandas as pd
import numpy as np
import networkx
import obonet
import json
import configparser

# %%
config_path = "../config/main.conf"
conf = configparser.ConfigParser()
conf.read(config_path)
# Out:
# ['../config/main.conf']

# %%
contact_maps = {}
for file in os.listdir('../data/contact_maps/sparse_matrices')[:10000]:
    if file.endswith('.npz'):
        pdb_code = file.split('.')[0]
        contact_map = scipy.sparse.load_npz('../data/contact_maps/sparse_matrices/' + file)
        contact_map.resize((3000, 3000))
        contact_maps[pdb_code] = contact_map

# %%
url = "http://purl.obolibrary.org/obo/go/go-basic.obo"
graph = obonet.read_obo(url)
goid_to_category = {id_: data.get('namespace') for id_, data in graph.nodes(data=True)}

# %%
df = pd.read_csv('../data/GO/pdb_chain_go.csv', skiprows = 1, error_bad_lines=False, warn_bad_lines = False)
df = df[['PDB', 'GO_ID']]
pdb_to_go = {}
for key, value in df.values:
    go_list = pdb_to_go.get(key.upper(), set())
    go_list.add(value)
    pdb_to_go[key.upper()] = go_list

# %%
with open("../data/contact_maps/pdb_sequences.json","r") as f:
    sequence_dict = json.load(f)

# %%
X_mf_data = []
y_mf_data = []
for key, value in contact_maps.items():
    go_list = []
    for go_term in pdb_to_go.get(key, []):
        if goid_to_category.get(go_term, '') == 'molecular_function':
            go_list.append(go_term)
    if len(go_list) > 0:
        X_mf_data.append((sequence_dict[key], value))
        y_mf_data.append(go_list)

# %%
mf_counts = {}
for labels in y_mf_data:
    for label in labels:
        mf_counts[label] = mf_counts.get(label, 0) + 1

# %%
removal_indices = []
for i in range(len(y_mf_data)):
    labels = y_mf_data[i]
    for label in labels:
        if mf_counts[label] < 25:
            labels.remove(label)
            if len(labels) == 0:
                removal_indices.append(i)
                
for i in reversed(removal_indices):
    X_mf_data.pop(i)
    y_mf_data.pop(i)

# %%
mf_terms = set()
for labels in y_mf_data:
    for label in labels:
        mf_terms.add(label)
        
mf_vocab = {mf: idx for idx, mf in enumerate(mf_terms)}
len(mf_vocab)
# Out:
# 593

# %%
# from utils/data.py
def prepare_sequence(seq, vocab, padding):
    """
    function to process the data, padding them
    TODO later will move to specific preprocessing part
    """
    res = ['<PAD>'] * padding
    res[:min(padding, len(seq))] = seq[:min(padding, len(seq))]
    # use 0 for padding
    idxs = [vocab[w] for w in res]
    return torch.tensor(idxs, dtype=torch.long)

vocab_path = '../config/genome_vocab.json'
with open(vocab_path, 'r') as of:
    vocab = json.load(of)

prepare_sequence(X_mf_data[0][0], vocab, 3000).shape
# Out:
# torch.Size([3000])

# %%
print(len(X_mf_data), len(y_mf_data))
# Out:
# 7420 7420

# %% [markdown]
# ### 2. Train Model

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_add_pool as gap
from torch_geometric.data import Data
from torch_geometric.utils import from_scipy_sparse_matrix
from torch_geometric.data import DataLoader
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
X_train_mf, X_val_mf, y_train_mf, y_val_mf = train_test_split(X_mf_data, y_mf_data, test_size=0.125, random_state=41)
dataset_train = []
for data, raw_labels in zip(X_train_mf, y_train_mf):
    x = prepare_sequence(data[0], vocab, 3000).float()
    edge_index = from_scipy_sparse_matrix(data[1])[0]
    labels = torch.tensor([mf_vocab[y] for y in raw_labels])
    targets = torch.zeros((len(mf_vocab)))
    targets[labels] = 1
    targets = torch.tensor(targets)
    dataset_train.append(Data(x = x, edge_index = edge_index, y = targets))
dataset_val = []
for data, raw_labels in zip(X_val_mf, y_val_mf):
    x = prepare_sequence(data[0], vocab, 3000).float()
    edge_index = from_scipy_sparse_matrix(data[1])[0]
    labels = torch.tensor([mf_vocab[y] for y in raw_labels])
    targets = torch.zeros((len(mf_vocab)))
    targets[labels] = 1
    targets = torch.tensor(targets)
    dataset_val.append(Data(x = x, edge_index = edge_index, y = targets))
# Out:
# /global/homes/n/nswenson/.conda/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.
# /global/homes/n/nswenson/.conda/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
language_model = torch.load('model_LSTM.attn_4epoch', map_location=torch.device('cpu'))
lm_embedding = language_model['model_state_dict']['module.word_embeddings.weight']
lm_embedding.shape
# Out:
# torch.Size([27, 80])

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.embedding = torch.nn.Embedding.from_pretrained(lm_embedding)
        self.conv1 = GCNConv(80, 128)
        self.conv2 = GCNConv(128, 128)
        self.conv3 = GCNConv(128, 256)
        self.linear1 = torch.nn.Linear(256, 512)
        self.linear2 = torch.nn.Linear(512, len(mf_vocab))

    def forward(self, data):
        
        x, edge_index, batch = data.x, data.edge_index, data.batch
                
        x = self.embedding(x.long())
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = gap(x, batch)
        x = self.linear1(x)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.linear2(x)
        x = torch.sigmoid(x)
        
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device).float()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005, weight_decay=5e-4)
train_loader = DataLoader(dataset_train, shuffle = True, batch_size=64)
model.train()
for epoch in range(20):
    for iteration, data in enumerate(train_loader):
        optimizer.zero_grad()
        out = model(data)
        criterion = torch.nn.BCELoss()
        loss = criterion(out, data.y.float().reshape(-1, len(mf_vocab)))
        loss.backward()
        optimizer.step()
        if iteration % 40 == 0:
            print(f'epoch {epoch + 1}, iteration {iteration}')
            print(f'loss = {loss}')
            pred = (out > 0.5).float()
            label = data.y.float().reshape(-1, len(mf_vocab))
            print('precision =', ((label * pred).sum()/label.sum()).item())
            print('recall =', ((label * pred).sum()/pred.sum()).item())
            print('total # of go terms =', label.sum().item())
            print('predicted # of go terms =', pred.sum().item())
            print()
# Out:
# epoch 1, iteration 0
# loss = 2.5587947368621826
# precision = 0.5746268630027771
# recall = 0.007982169277966022
# total # of go terms = 268.0
# predicted # of go terms = 19293.0
#
# epoch 1, iteration 40
# loss = 0.4654340445995331
# precision = 0.18241041898727417
# recall = 0.00860611628741026
# total # of go terms = 307.0
# predicted # of go terms = 6507.0
#
# epoch 1, iteration 80
# loss = 0.1372823566198349
# precision = 0.04545454680919647
# recall = 0.009188361465930939
# total # of go terms = 264.0
# predicted # of go terms = 1306.0
#
# epoch 2, iteration 0
# loss = 0.0759175568819046
# precision = 0.06086956337094307
# recall = 0.029723990708589554
# total # of go terms = 230.0
# predicted # of go terms = 471.0
#
# epoch 2, iteration 40
# loss = 0.06926358491182327
# precision = 0.04642857238650322
# recall = 0.05179283022880554
# total # of go terms = 280.0
# predicted # of go terms = 251.0
#
# epoch 2, iteration 80
# loss = 0.05172669515013695
# precision = 0.07058823853731155
# recall = 0.1090909093618393
# total # of go terms = 255.0
# predicted # of go terms = 165.0
#
# epoch 3, iteration 0
# loss = 0.05524684488773346
# precision = 0.07508532702922821
# recall = 0.13017751276493073
# total # of go terms = 293.0
# predicted # of go terms = 169.0
#
# epoch 3, iteration 40
# loss = 0.053758684545755386
# precision = 0.048507463186979294
# recall = 0.0878378376364708
# total # of go terms = 268.0
# predicted # of go terms = 148.0
#
# epoch 3, iteration 80
# loss = 0.04581962153315544
# precision = 0.05923344939947128
# recall = 0.1349206417798996
# total # of go terms = 287.0
# predicted # of go terms = 126.0
#
# epoch 4, iteration 0
# loss = 0.04560749977827072
# precision = 0.05283018946647644
# recall = 0.10526315867900848
# total # of go terms = 265.0
# predicted # of go terms = 133.0
#
# epoch 4, iteration 40
# loss = 0.04569106921553612
# precision = 0.03212851285934448
# recall = 0.07339449226856232
# total # of go terms = 249.0
# predicted # of go terms = 109.0
#
# epoch 4, iteration 80
# loss = 0.04452331364154816
# precision = 0.05144694447517395
# recall = 0.17777778208255768
# total # of go terms = 311.0
# predicted # of go terms = 90.0
#
# epoch 5, iteration 0
# loss = 0.050813015550374985
# precision = 0.04956268146634102
# recall = 0.1683168262243271
# total # of go terms = 343.0
# predicted # of go terms = 101.0
#
# epoch 5, iteration 40
# loss = 0.0390096940100193
# precision = 0.062043797224760056
# recall = 0.1931818127632141
# total # of go terms = 274.0
# predicted # of go terms = 88.0
#
# epoch 5, iteration 80
# loss = 0.0399513766169548
# precision = 0.04482758790254593
# recall = 0.22033898532390594
# total # of go terms = 290.0
# predicted # of go terms = 59.0
#
# epoch 6, iteration 0
# loss = 0.0398169681429863
# precision = 0.046204619109630585
# recall = 0.21212121844291687
# total # of go terms = 303.0
# predicted # of go terms = 66.0
#
# epoch 6, iteration 40
# loss = 0.03352462127804756
# precision = 0.09689922630786896
# recall = 0.3333333432674408
# total # of go terms = 258.0
# predicted # of go terms = 75.0
#
# epoch 6, iteration 80
# loss = 0.03443513065576553
# precision = 0.07450980693101883
# recall = 0.28787878155708313
# total # of go terms = 255.0
# predicted # of go terms = 66.0
#
# epoch 7, iteration 0
# loss = 0.03788984566926956
# precision = 0.04089219495654106
# recall = 0.18333333730697632
# total # of go terms = 269.0
# predicted # of go terms = 60.0
#
# epoch 7, iteration 40
# loss = 0.032786108553409576
# precision = 0.03921568766236305
# recall = 0.17543859779834747
# total # of go terms = 255.0
# predicted # of go terms = 57.0
#
# epoch 7, iteration 80
# loss = 0.03430354595184326
# precision = 0.05514705926179886
# recall = 0.2830188572406769
# total # of go terms = 272.0
# predicted # of go terms = 53.0
#
# epoch 8, iteration 0
# loss = 0.03336615115404129
# precision = 0.040145985782146454
# recall = 0.25581395626068115
# total # of go terms = 274.0
# predicted # of go terms = 43.0
#
# epoch 8, iteration 40
# loss = 0.030611002817749977
# precision = 0.052401747554540634
# recall = 0.3076923191547394
# total # of go terms = 229.0
# predicted # of go terms = 39.0
#
# epoch 8, iteration 80
# loss = 0.03718729317188263
# precision = 0.03536977618932724
# recall = 0.29729729890823364
# total # of go terms = 311.0
# predicted # of go terms = 37.0
#
# epoch 9, iteration 0
# loss = 0.03029536083340645
# precision = 0.042016807943582535
# recall = 0.24390244483947754
# total # of go terms = 238.0
# predicted # of go terms = 41.0
#
# epoch 9, iteration 40
# loss = 0.025886371731758118
# precision = 0.0276497695595026
# recall = 0.1666666716337204
# total # of go terms = 217.0
# predicted # of go terms = 36.0
#
# epoch 9, iteration 80
# loss = 0.03432772681117058
# precision = 0.0714285746216774
# recall = 0.45652174949645996
# total # of go terms = 294.0
# predicted # of go terms = 46.0
#
# epoch 10, iteration 0
# loss = 0.03029583767056465
# precision = 0.0749063640832901
# recall = 0.5555555820465088
# total # of go terms = 267.0
# predicted # of go terms = 36.0
#
# epoch 10, iteration 40
# loss = 0.028491925448179245
# precision = 0.07468879967927933
# recall = 0.5454545617103577
# total # of go terms = 241.0
# predicted # of go terms = 33.0
#
# epoch 10, iteration 80
# loss = 0.02976810187101364
# precision = 0.03703703731298447
# recall = 0.28125
# total # of go terms = 243.0
# predicted # of go terms = 32.0
#
# epoch 11, iteration 0
# loss = 0.0367281511425972
# precision = 0.04968944191932678
# recall = 0.5517241358757019
# total # of go terms = 322.0
# predicted # of go terms = 29.0
#
# epoch 11, iteration 40
# loss = 0.03252642974257469
# precision = 0.06737588346004486
# recall = 0.5
# total # of go terms = 282.0
# predicted # of go terms = 38.0
#
# epoch 11, iteration 80
# loss = 0.02872869372367859
# precision = 0.07258064299821854
# recall = 0.529411792755127
# total # of go terms = 248.0
# predicted # of go terms = 34.0
#
# epoch 12, iteration 0
# loss = 0.03070013038814068
# precision = 0.07058823853731155
# recall = 0.44999998807907104
# total # of go terms = 255.0
# predicted # of go terms = 40.0
#
# epoch 12, iteration 40
# loss = 0.028773291036486626
# precision = 0.09473684430122375
# recall = 0.6279069781303406
# total # of go terms = 285.0
# predicted # of go terms = 43.0
#
# epoch 12, iteration 80
# loss = 0.027950363233685493
# precision = 0.11152416467666626
# recall = 0.7692307829856873
# total # of go terms = 269.0
# predicted # of go terms = 39.0
#
# epoch 13, iteration 0
# loss = 0.03251447528600693
# precision = 0.128742516040802
# recall = 0.6935483813285828
# total # of go terms = 334.0
# predicted # of go terms = 62.0
#
# epoch 13, iteration 40
# loss = 0.03248937427997589
# precision = 0.12999999523162842
# recall = 0.6290322542190552
# total # of go terms = 300.0
# predicted # of go terms = 62.0
#
# epoch 13, iteration 80
# loss = 0.030105285346508026
# precision = 0.06949806958436966
# recall = 0.5806451439857483
# total # of go terms = 259.0
# predicted # of go terms = 31.0
#
# epoch 14, iteration 0
# loss = 0.02991136536002159
# precision = 0.11428571492433548
# recall = 0.6808510422706604
# total # of go terms = 280.0
# predicted # of go terms = 47.0
#
# epoch 14, iteration 40
# loss = 0.02598157338798046
# precision = 0.06530611962080002
# recall = 0.5925925970077515
# total # of go terms = 245.0
# predicted # of go terms = 27.0
#
# epoch 15, iteration 0
# loss = 0.026000330224633217
# precision = 0.1587301641702652
# recall = 0.7142857313156128
# total # of go terms = 252.0
# predicted # of go terms = 56.0
#
# epoch 15, iteration 40
# loss = 0.022631976753473282
# precision = 0.17004048824310303
# recall = 0.875
# total # of go terms = 247.0
# predicted # of go terms = 48.0
#
# epoch 15, iteration 80
# loss = 0.03301191329956055
# precision = 0.1319648027420044
# recall = 0.7758620977401733
# total # of go terms = 341.0
# predicted # of go terms = 58.0
#
# epoch 16, iteration 0
# loss = 0.0279226154088974
# precision = 0.10071942210197449
# recall = 0.7777777910232544
# total # of go terms = 278.0
# predicted # of go terms = 36.0
#
# epoch 16, iteration 40
# loss = 0.024089129641652107
# precision = 0.10087719559669495
# recall = 0.5897436141967773
# total # of go terms = 228.0
# predicted # of go terms = 39.0
#
# epoch 16, iteration 80
# loss = 0.02621409110724926
# precision = 0.1171875
# recall = 0.7692307829856873
# total # of go terms = 256.0
# predicted # of go terms = 39.0
#
# epoch 17, iteration 0
# loss = 0.024327050894498825
# precision = 0.17842324078083038
# recall = 0.7288135886192322
# total # of go terms = 241.0
# predicted # of go terms = 59.0
#
# epoch 17, iteration 40
# loss = 0.02405458316206932
# precision = 0.09243697673082352
# recall = 0.7333333492279053
# total # of go terms = 238.0
# predicted # of go terms = 30.0
#
# epoch 17, iteration 80
# loss = 0.027418583631515503
# precision = 0.06692913174629211
# recall = 0.53125
# total # of go terms = 254.0
# predicted # of go terms = 32.0
#
# epoch 18, iteration 0
# loss = 0.029230382293462753
# precision = 0.13432836532592773
# recall = 0.7659574747085571
# total # of go terms = 268.0
# predicted # of go terms = 47.0
#
# epoch 18, iteration 40
# loss = 0.021916760131716728
# precision = 0.27799227833747864
# recall = 0.9113923907279968
# total # of go terms = 259.0
# predicted # of go terms = 79.0
#
# epoch 18, iteration 80
# loss = 0.028852706775069237
# precision = 0.1708860695362091
# recall = 0.8571428656578064
# total # of go terms = 316.0
# predicted # of go terms = 63.0
#
# epoch 19, iteration 0
# loss = 0.029745308682322502
# precision = 0.12987013161182404
# recall = 0.7692307829856873
# total # of go terms = 308.0
# predicted # of go terms = 52.0
#
# epoch 19, iteration 40
# loss = 0.0298092570155859
# precision = 0.125
# recall = 0.9166666865348816
# total # of go terms = 264.0
# predicted # of go terms = 36.0
#
# epoch 19, iteration 80
# loss = 0.02504451386630535
# precision = 0.1863117814064026
# recall = 0.8166666626930237
# total # of go terms = 263.0
# predicted # of go terms = 60.0
#
# epoch 20, iteration 0
# loss = 0.02360171638429165
# precision = 0.18897637724876404
# recall = 0.8275862336158752
# total # of go terms = 254.0
# predicted # of go terms = 58.0
#
# epoch 20, iteration 40
# loss = 0.026618463918566704
# precision = 0.16725978255271912
# recall = 0.8103448152542114
# total # of go terms = 281.0
# predicted # of go terms = 58.0
#
# epoch 20, iteration 80
# loss = 0.02415829338133335
# precision = 0.21641790866851807
# recall = 0.8285714387893677
# total # of go terms = 268.0
# predicted # of go terms = 70.0

# %%
model.eval()
val_loader = DataLoader(dataset_val, batch_size = 64)
with torch.no_grad():
    train_logits = {}
    val_logits = {}
    train_labels = {}
    val_labels = {}
    train_precisions = []
    train_recalls = []
    val_precisions = []
    val_recalls = []
    for thresh in np.arange(0.01, .91, .001):
        train_precision = 0.0
        train_recall = 0.0
        train_num_batches = 0.0
        for idx, data in enumerate(train_loader):
            data = data.to(device)
            if idx in train_logits:
                pred = (train_logits[idx] > thresh).float()
                label = train_labels[idx]
            else:
                logits = model(data)
                train_logits[idx] = logits
                pred = (logits > thresh).float()
                label = data.y.float().reshape(-1, len(mf_vocab))
                train_labels[idx] = label
            train_precision += ((label * pred).sum()/label.sum()).item()
            train_recall += ((label * pred).sum()/pred.sum()).item()
            train_num_batches += 1
        #print('precision = ', train_precision/train_num_batches)
        #print('recall = ', train_recall/train_num_batches)
        train_precisions.append(train_precision/train_num_batches)
        train_recalls.append(train_recall/train_num_batches)
        
        val_precision = 0.0
        val_recall = 0.0
        val_num_batches = 0.0
    
        for data in val_loader:
            data = data.to(device) 
            if idx in val_logits:
                pred = (val_logits[idx] > thresh).float()
                label = val_labels[idx]
            else:
                logits = model(data)
                val_logits[idx] = logits
                pred = (logits > thresh).float()
                label = data.y.float().reshape(-1, len(mf_vocab))
                val_labels[idx] = label
            val_precision += ((label * pred).sum()/label.sum()).item()
            val_recall += ((label * pred).sum()/pred.sum()).item()
            val_num_batches += 1
        #print('precision = ', val_precision/val_num_batches)
        #print('recall = ', val_recall/val_num_batches)
        val_precisions.append(val_precision/val_num_batches)
        val_recalls.append(val_recall/val_num_batches)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import auc
plt.plot(train_precisions, train_recalls)
plt.plot(val_precisions, train_recalls)
plt.title('Averaged Precision Recall for Training data')
plt.legend([f'train auc = {round(auc(train_precisions, train_recalls), 3)}', f'val auc = {round(auc(val_precisions, train_recalls), 3)}'])
plt.xlabel('Precision')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# ###
